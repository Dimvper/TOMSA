# %% [markdown]
# <span style="color:#a33f1f;text-align:center">
#
# # MEEC/SA - TOMSA 2022/2023
# ## TRAB1 - Título do trabalho
# <span style="color:#000000;text-align:left">
#
# #### Realizado por:
#
# > #### Número - Nome
# > #### Número - Nome
# > #### Data:

# %% [markdown]
# ## Conteúdo
# [1.](#i1) Resumo
#
# [2.](#i2) Enquadramento
#
# [3.](#i3)  Código realizado
#
# [4.](#i4) Execução

# %% [markdown]
# <span id="i1"></span>
#
# ## 1. Resumo
#
# Pequeno descrição do trabalho apresentado no documento com ênfase na utilização do código realizado.

# %% [markdown]
# <span id="i2"></span>
#
# ## 2. Equadramento
#
# Apresentação teórica do tema escolhido com ênfase no rigor quer de conteúdo, quer da utilização da linguagem Marldown e em particular do $\LaTeX$ no escrever de expressões matemáticas. O número de subsecções é responsabilidde dos autores. As imagens  incluídas devem ser, nos caso se justifique, sempre referenciadas (ver Figura [[1](#fig1)]). Sugere-se para as referências bibliográficas o formato IEEE [[1](#ref1)] que pode ser implementado em linguagem Markdown do Jupyter como no exemplo fornecido para o livro [[2](#ref2)].
#
# ![image-2.png](attachment:image-2.png)
#
# <span id="fig1">_Figura 1_: Classic Euler angles geometrical definition[[3](#ref3)]</span>

# %% [markdown]
# ###  2.1   ***

# %% [markdown]
# ###  Referências
# <span id="ref1">[1] _ieeeauthorcenter.ieee.org_, 2021. [Online]. Available: https://ieeeauthorcenter.ieee.org/wp-content/uploads/IEEE-Reference-Guide.pdf. [Accessed: 17- Oct- 2021].</span>
#
# <span id="ref2">[2] R. Brannon, _Rotation, reflection, and frame changes_. Bristol: Institute of physics, 2018.</span>
#
# <span id="ref3">[3] “Euler angles,” _Wikipedia_, 09-Sep-2021. [Online]. Available: https://en.wikipedia.org/wiki/Euler_angles. [Accessed: 17-Oct-2021]. </span>

# %% [markdown]
# <span id="i3"></span>
#
# ## 3. Código realizado
#
# Código Python...

# %% [markdown]
# <span id="i4"></span>
#
# ## 4. Execução
#
# Exemplo de aplicação funcional usado para teste e que poderá ser adaptado e alterado
